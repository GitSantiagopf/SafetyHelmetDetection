# %%
# !pip install roboflow
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/4f/2c/13ef4a1811365208f7441dae564ea57dad4b58762196b7d8e65860b0cc07/roboflow-1.1.7-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/155.3 kB ? eta -:--:--
#      ------- -------------------------------- 30.7/155.3 kB ? eta -:--:--
#      ------------------------------ ------- 122.9/155.3 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 155.3/155.3 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#      ---------------------------- --------- 133.1/178.7 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 178.7/178.7 kB 2.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB 1.6 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/01/0b/b337c3dbd54e3f59471baccb2867508981638c0435dbef3e923a27484d6b/ultralytics-8.0.198-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opencv-python>=4.6.0 from https://files.pythonhosted.org/packages/38/d2/3e8c13ffc37ca5ebc6f382b242b44acb43eb489042e1728407ac3904e72f/opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/fa/47/1a7daf04f40715fc1cdc6f1cc3200228a556d06c843e6ceb58883b745e1b/torch-2.1.0-cp310-cp310-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for torchvision>=0.9.0 from https://files.pythonhosted.org/packages/59/af/426c2b90f5c4f8aba778746465af9e662680570e950e02379e91c6138285/torchvision-0.16.0-cp310-cp310-win_amd64.whl.metadata
# ...

# %%
from ultralytics import YOLO
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="SllqtgO2lGUPwjwUdvLs")
project = rf.workspace("universidad-nacional-de-colombia-altwu").project("cascos-xtsep")
dataset = project.version(3).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.198, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to cascos-3 in yolov8:: 100%|██████████| 19258/19258 [00:06<00:00, 2921.36it/s]

# %%
model = YOLO('yolov8n.pt')

# %%
rf = Roboflow(api_key="--------") #Use you apikey
project = rf.workspace("-----").project("-----")
dataset = project.version(4).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.188, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Safety-helmet-4 in yolov8:: 100%|██████████| 818/818 [00:00<00:00, 3804.25it/s]

# %%
# !nvidia-smi
# Out:
# Fri Oct 13 17:11:10 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.58                 Driver Version: 537.58       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080      WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   35C    P8               9W / 320W |    682MiB / 16376MiB |      8%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.198  Python-3.10.13 torch-2.1.0 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# Setup complete  (16 CPUs, 31.8 GB RAM, 52.0/698.6 GB disk)

# %%
data = 'D:\Desktop\Proyecto ingelam\SafetyHelmetDetection\safetyhelmetdetection\cascos-3\data.yaml'
model.train(data = data, epochs = 1000)
# Out:
# New https://pypi.org/project/ultralytics/8.0.200 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.198  Python-3.10.13 torch-2.1.0 CUDA:0 (NVIDIA GeForce RTX 4080, 16376MiB)
# ...
