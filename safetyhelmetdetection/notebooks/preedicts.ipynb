# %%
from ultralytics import YOLO
import cv2
import numpy as np
from IPython.display import display, clear_output
import PIL.Image
import io
import torch
import matplotlib.pyplot as plt

# %%
#Best model
model = YOLO('best (3).pt')

# %%
# Perform object detection using your YOLOv8 model on the single image
image = cv2.imread('hardhat2.jpg')
results = model(image)
frame = results[0].plot()
plt.imshow(frame)
# Out:
# 0: 640x640 1 -con_casco-, 6 -sin_casco-s, 178.5ms
# Speed: 4.5ms preprocess, 178.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
cap = cv2.VideoCapture('hard.mp4')

while True:
    # Read a frame from the video
    ret, frame = cap.read()

    results = model(frame)

    print(results[0])
    frame = results[0].plot()


    cv2.imshow('Detección de casco', frame)
    
    if cv2.waitKey(30) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(1)

while True:
    ret, frame = cap.read()

    if not ret:
        break

    # Convert the BGR frame to RGB format
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    results = model(frame_rgb)

    frame_rgb = results[0].plot()

    # Display the RGB frame in the Colab notebook
    clear_output(wait=True)
    display(PIL.Image.fromarray(frame_rgb))

# Release the webcam capture
cap.release()
cap.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\LagAl\OneDrive\Escritorio\main.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> # Perform object detection using your model
#      <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a> # Assuming your model takes a frame as input and returns results
# ---> <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> results = model(frame_rgb)
#      <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> # Visualize the results (you may need to customize this part)
#      <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a> # Assuming results[0] contains the processed frame
#      <a href='vscode-notebook-cell:/c%3A/Users/LagAl/OneDrive/Escritorio/main.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> frame_rgb = results[0].plot()
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:96, in Model.__call__(self, source, stream, **kwargs)
#      94 def __call__(self, source=None, stream=False, **kwargs):
#      95     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 96     return self.predict(source, stream, **kwargs)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py:236, in Model.predict(self, source, stream, predictor, **kwargs)
#     234 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     235     self.predictor.set_prompts(prompts)
# --> 236 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:194, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     192     return self.stream_inference(source, model, *args, **kwargs)
#     193 else:
# --> 194     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\predictor.py:133, in BasePredictor.inference(self, im, *args, **kwargs)
#     130 def inference(self, im, *args, **kwargs):
#     131     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     132                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 133     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\autobackend.py:333, in AutoBackend.forward(self, im, augment, visualize)
#     330     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     332 if self.pt or self.nn_module:  # PyTorch
# --> 333     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     334 elif self.jit:  # TorchScript
#     335     y = self.model(im)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\modules\block.py:134, in SPPF.forward(self, x)
#     132 y1 = self.m(x)
#     133 y2 = self.m(y1)
# --> 134 return self.cv2(torch.cat((x, y1, y2, self.m(y2)), 1))
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\nn\modules\conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\activation.py:396, in SiLU.forward(self, input)
#     395 def forward(self, input: Tensor) -> Tensor:
# --> 396     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\LagAl\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\functional.py:2058, in silu(input, inplace)
#    2056     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2057 if inplace:
# -> 2058     return torch._C._nn.silu_(input)
#    2059 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:
